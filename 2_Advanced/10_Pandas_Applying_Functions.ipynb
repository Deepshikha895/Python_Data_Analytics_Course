# %%
#importing required packages

import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast

#loading dataset
dataset=load_dataset('lukebarousse/data_jobs')
#forming a dataframe
df = dataset['train'].to_pandas()


#data cleanup converting date column to date timetype from string type.
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

# %%
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df['job_skills'].head(10)
# Out:
# 0                                                 None
# 1           [r, python, sql, nosql, power bi, tableau]
# 2    [python, sql, c#, azure, airflow, dax, docker,...
# 3    [python, c++, java, matlab, aws, tensorflow, k...
# 4    [bash, python, oracle, aws, ansible, puppet, j...
# 5                                   [python, sql, gcp]
# 6    [sql, python, java, sql server, gcp, bigquery,...
# 7    [sql, nosql, gcp, azure, aws, bigquery, databr...
# 8                        [excel, powerpoint, power bi]
# 9    [sql, python, r, mongodb, mongodb, sql server,...
# Name: job_skills, dtype: object

# %%
df['job_skills'] = df['job_skills'].apply(
                    lambda skill_list: ast.literal_eval(skill_list) if isinstance(skill_list, str) else skill_list)

# %%
df_sal = df[pd.notna(df['salary_year_avg'])].copy() 
#df.info()

# %%
df_sal
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_sal['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df_sal['salary_year_projected'] = df_sal['salary_year_avg'].apply(lambda salary: salary * 1.03)

# %%
#df_sal[('salary_year_avg', 'salary_year_projected')]
df_sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
df_sal[['salary_year_avg', 'salary_year_projected']]
# Out:
#         salary_year_avg  salary_year_projected
# 28             109500.0              112785.00
# 77             140000.0              144200.00
# 92             120000.0              123600.00
# 100            228222.0              235068.66
# 109             89000.0               91670.00
# ...                 ...                    ...
# 785624         139216.0              143392.48
# 785641         150000.0              154500.00
# 785648         221875.0              228531.25
# 785682         157500.0              162225.00
# 785692         157500.0              162225.00
#
# [22003 rows x 2 columns]

# %%
def projected_sal(row):
    if "Senior" in row["job_title_short"]:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']

df_sal['salary_year_projected']=df_sal.apply(projected_sal, axis=1)
df_sal[['job_title_short', 'salary_year_avg', 'salary_year_projected']].tail(15)
# Out:
#               job_title_short  salary_year_avg  salary_year_projected
# 785187           Data Analyst         111175.0             114510.250
# 785195         Data Scientist         150000.0             154500.000
# 785290         Data Scientist         224500.0             231235.000
# 785324         Data Scientist         234500.0             241535.000
# 785330  Senior Data Scientist         200935.5             210982.275
# 785340  Senior Data Scientist         196800.0             206640.000
# 785395          Data Engineer          64800.0              66744.000
# 785488         Data Scientist         115000.0             118450.000
# 785515           Data Analyst         105000.0             108150.000
# 785563         Data Scientist         136400.0             140492.000
# 785624          Data Engineer         139216.0             143392.480
# 785641          Data Engineer         150000.0             154500.000
# ...
